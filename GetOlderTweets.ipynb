# %%
# Mount your google drive to the colab environment
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# clone the required library from the Github to get older tweets
# !git clone https://github.com/Jefferson-Henrique/GetOldTweets-python.git
# Out:
# Cloning into 'GetOldTweets-python'...
# remote: Enumerating objects: 230, done.
# remote: Total 230 (delta 0), reused 0 (delta 0), pack-reused 230
# Receiving objects: 100% (230/230), 45.18 KiB | 367.00 KiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# go to the proper directory and also install pyquery library to run the codes
# %cd /content/GetOldTweets-python/
# !ls

# !pip install pyquery==1.2.10
# Out:
# /content/GetOldTweets-python
# exporter_help_text.txt	got   LICENSE  README.md
# Exporter.py		got3  Main.py  requirements.txt
# Collecting pyquery==1.2.10
#   Downloading https://files.pythonhosted.org/packages/a8/85/2cc9fef69eafe2f65e090690b5c46bbb0a45e81bf1e2096bc0ace7f46b6a/pyquery-1.2.10.tar.gz (43kB)
#      |████████████████████████████████| 51kB 4.3MB/s
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.6/dist-packages (from pyquery==1.2.10) (4.2.6)
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Building wheels for collected packages: pyquery
#   Building wheel for pyquery (setup.py) ... done
#   Created wheel for pyquery: filename=pyquery-1.2.10-cp36-none-any.whl size=19235 sha256=bdaf3a6b401a8d428225cb3d6ecb0b66235f15ed5ae3211efa23500271fa78e6
#   Stored in directory: /root/.cache/pip/wheels/88/46/56/64827a3a40b94ce29e5d61ebc82deec2e2ee9695c55b0549ad
# Successfully built pyquery
# Installing collected packages: cssselect, pyquery
# Successfully installed cssselect-1.1.0 pyquery-1.2.10

# %%
# Get Older Tweets
import got3
import pandas as pd



# set the criteria for your desired tweets
tweetCriteria = got3.manager.TweetCriteria().setQuerySearch('#AIDebate').setSince("2019-12-22").setUntil("2020-01-01").setMaxTweets(100000000)
tweets = got3.manager.TweetManager.getTweets(tweetCriteria) #collect data

#write the tweets' data in a dictionary
rows_list = []
for tweet in tweets:
  tweet_data = {
      "ID": str(tweet.id),
      "permalink": str(tweet.permalink),
      "username": str(tweet.username),
      "text": str(tweet.text),
      "date": str(tweet.date),
      "formatted_date": str(tweet.formatted_date),
      "retweets": str(tweet.retweets),
      "favorites": str(tweet.favorites),
      "mentions": str(tweet.mentions),
      "hashtags": str(tweet.hashtags),
      "geo": str(tweet.geo),
      "urls": str(tweet.urls),
      "author_id": str(tweet.author_id)
  }
  rows_list.append(tweet_data)



df = pd.DataFrame(rows_list) 
df.to_csv('/content/gdrive/My Drive/Colab Notebooks/Twitter_Analysis/ALL_tweets_with_hashtag_AIDebate.csv')
print(df)
  # # write the data to a file in a json format
  # with open('/content/gdrive/My Drive/Colab Notebooks/Twitter_Analysis/ALL_tweets_with_hashtag_AIDebate.txt', 'a') as the_file:
  #   the_file.write(str(tweet_data) + '\n')
  #   print(str(tweet_data) + '\n')
# Out:
#                       ID  ...           author_id
# 0    1212062633546919936  ...           919860212
# 1    1212058809839042560  ...           562399749
# 2    1212056956774604801  ...           919860212
# 3    1212019750194286599  ...  843679027613356032
# 4    1212010734009430017  ...           919860212
# ..                   ...  ...                 ...
# 435  1208824455671242752  ...           919860212
# 436  1208817023289090050  ...            20748873
# 437  1208765874246737920  ...          2437237957
# 438  1208764458090323976  ...          2345198082
# 439  1208764083954163716  ...           176540776
#
# [440 rows x 13 columns]

# %%
#get number of tweets
len(tweets)
# Out:
# 440
